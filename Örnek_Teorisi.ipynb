# %% [markdown]
# VERİ BİLİMİ İÇİN İSTATİSTİK

# %%
#Örnek Teorisi
import numpy as np

# %%
# 0-80 Yaş arası 100000 kişilik bir popülasyon
populasyon=np.random.randint(0,80,10000)

# %%
populasyon[0:10]
# Out:
# array([69, 36, 54, 54, 44, 62, 69, 16,  0, 15])

# %%
#Örneklem Çekimi
np.random.seed(115)
orneklem=np.random.choice(a=populasyon,size=100) #rastgele 100 kişi çek
orneklem[0:10]
# Out:
# array([ 4, 27, 17, 71, 62,  6,  4, 46,  8, 55])

# %%
#Örneklemin ortalaması
orneklem.mean()
# Out:
# 42.44

# %%
#Popülasyon ortalaması
populasyon.mean()
# Out:
# 39.9329

# %%
#Örneklem Dağılımı
np.random.seed(10)
orneklem1=np.random.choice(a=populasyon,size=100)
orneklem2=np.random.choice(a=populasyon,size=100)
orneklem3=np.random.choice(a=populasyon,size=100)
orneklem4=np.random.choice(a=populasyon,size=100)
orneklem5=np.random.choice(a=populasyon,size=100)
orneklem6=np.random.choice(a=populasyon,size=100)
orneklem7=np.random.choice(a=populasyon,size=100)
orneklem8=np.random.choice(a=populasyon,size=100)
orneklem9=np.random.choice(a=populasyon,size=100)
orneklem10=np.random.choice(a=populasyon,size=100)

# %%
(orneklem1.mean()+orneklem2.mean()+orneklem3.mean()+orneklem4.mean()+orneklem5.mean()+orneklem6.mean()+orneklem7.mean()+orneklem8.mean()+orneklem9.mean()+orneklem10.mean())/10
# Out:
# 39.921

# %% [markdown]
# KOVERYANS:İKİ DEĞİŞKEN ARASINDA İLİŞKİNİN DEĞİŞKENLİK ÖLÇÜSÜ

# %% [markdown]
# KORELASYON:İKİ DEĞİŞKEN ARASINDA İLİŞKİ ANLAMINA BAKAN İSTATİKSEL TEKNİKTİR

# %% [markdown]
# BETİMSEL İSTATİSTİKLER

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
df=tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
# !pip install researchpy
import researchpy as rp

# %%
rp.summary_cont(df[["total_bill","tip","size"]])
# Out:
# /usr/local/lib/python3.10/dist-packages/researchpy/summary.py:102: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'total_bill' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   table_a.iloc[0,0] = ix
# /usr/local/lib/python3.10/dist-packages/researchpy/summary.py:102: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'tip' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   table_a.iloc[0,0] = ix
# /usr/local/lib/python3.10/dist-packages/researchpy/summary.py:102: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'size' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   table_a.iloc[0,0] = ix
# ...

# %%
rp.summary_cat(df[['sex','smoker','day']])
# Out:
#   Variable Outcome  Count  Percent
# 0      sex    Male    157    64.34
# 1           Female     87    35.66
# 2   smoker      No    151    61.89
# 3              Yes     93    38.11
# 4      day     Sat     87    35.66
# 5              Sun     76    31.15
# 6             Thur     62    25.41
# 7              Fri     19     7.79

# %%
df[['tip','total_bill']].cov()
# Out:
#                  tip  total_bill
# tip         1.914455    8.323502
# total_bill  8.323502   79.252939

# %%
#Korelasyon ilişkisine bakalım
df[['tip','total_bill']].corr()
# Out:
#                  tip  total_bill
# tip         1.000000    0.675734
# total_bill  0.675734    1.000000
